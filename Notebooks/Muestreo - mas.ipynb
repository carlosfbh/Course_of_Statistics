# %%
# %pylab inline
from scipy import stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mi_normal=stats.norm(2,0.5)

# %%
ne = np.linspace(-1,4,1000)
ye = list(map(mi_normal.pdf,ne))
plt.plot(ne,ye)

# %%
sample=mi_normal.rvs(10)

# %%
np.mean(sample)
# Out:
# 2.2312630940855742

# %%
n=10
mi_t=stats.t(n-1)

# %%
#s=0.5
s=np.std(sample)

# %%
ne = np.linspace(-3,4,1000)
ye = list(map(mi_t.pdf,(ne-2)/(s/math.sqrt(n))))
plt.plot(ne,ye)

# %%
ne = np.linspace(-3,4,1000)
ye = list(map(mi_t.pdf,(ne-2)/(s/math.sqrt(n))))
plt.plot(ne,ye)

nep = np.linspace(2.08,4,1000)
yep = list(map(mi_t.pdf,(nep-2)/(s/math.sqrt(n))))
plt.fill_between(x=nep,y1=yep)

# %%
# Hipotesis Media 2
# Muestra : 5
1-mi_t.cdf( (5-2)/(s/math.sqrt(n)) )
# Out:
# 1.6746931619238126e-08

# %%
5%
